# %% [markdown]
# # Analise sobre ataque de tubarões
# ## Perguntas:
# - Anos com mais ataques?
# - Paises com mais ataques?
#
#     No futuro:
# - Dos encontros de tubarões quantos são fateis e quantos a vitima sai ilesa?
# - Quais são as especies que mais atacam
#
#     Teste de Hipoteses
# - Uma parte siginificativa dos ataques não são ataqueis de fato, os seres humanos não são a principal alimento dos tubarões

# %% [markdown]
# ## Importação

# %%
import pandas as pd

# %%
shark = pd.read_csv(r'C:\Users\rober\Desktop\code study\projetos\shark_attk_projet_1\attacks.csv', encoding = 'latin1')

# %% [markdown]
# ## Metodos de Reconhecimento

# %%
shark.head(12)
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5   2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6   2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7     2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8   2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9   2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
# 10    2018.05.24  24-May-2018  2018.0    Provoked  AUSTRALIA       Queensland
# ...

# %%
shark.info
# Out:
# <bound method DataFrame.info of       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# ...

# %%
print(shark.shape)
print(shark.dtypes)
shark.columns
# Out:
# (25723, 24)
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
# ...

# %% [markdown]
# ## Limpeza de nulos, corte de dados nao relevantes para a analise, reorganizacao do datafreme

# %% [markdown]
# ### As Colunas a baixo não serão usadas na analise pois estão sem dados suficientes ou não fazem parte do objetivo da analise

# %%
shark = shark.drop(columns=['Unnamed: 22', 'Unnamed: 23', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order','Investigator or Source','Location'])

# %%
shark.head(50)
# Out:
#      Case Number                  Date    Year          Type        Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating            USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked            USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid            USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked         MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked      AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked         BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked            USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked            USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked            USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked      AUSTRALIA
# ...

# %% [markdown]
# ### Extração de nulos

# %%
shark.isnull().sum()
# Out:
# Case Number    17021
# Date           19421
# Year           19423
# Type           19425
# Country        19471
# Area           19876
# Activity       19965
# Name           19631
# Sex            19986
# Age            22252
# Injury         19449
# Fatal (Y/N)    19960
# Time           22775
# Species        22259
# dtype: int64

# %%
shark = shark.dropna()

# %%
shark['Year'].isnull().sum()
# Out:
# 0

# %%
# Algumas tentativas e testes.

#shark = shark.dropna(subset = ['Year'])
#shark.isnull().sum(axis = 1)
#n_missings =  shark.isnull().sum() 
#n_missings > shark.isnull().sum()
#n_missings.loc[n_missings > 0]

#shark['Date'] = shark['Date'].astype( dtype = str)

#pattern = "[0-9]{3}"
#print(re.findall(pattern,shark['Date']))

# %% [markdown]
# ### Reordenação

# %%
shark = shark[['Year', 'Date','Country','Area','Type', 'Fatal (Y/N)','Species ', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Time']]

# %% [markdown]
# ### Regex teste

# %%
import re

# %%
shark['Data'] = shark['Date'].str.extract('([0-9]{3,})')

# %%
shark.head(20)
# Out:
#      Case Number         Date    Year        Type       Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating           USA
# 6   2018.06.03.a  03-Jun-2018  2018.0  Unprovoked        BRAZIL
# 8   2018.05.26.b  26-May-2018  2018.0  Unprovoked           USA
# 10    2018.05.24  24-May-2018  2018.0    Provoked     AUSTRALIA
# 13  2018.05.13.a  13-May-2018  2018.0     Invalid       ENGLAND
# 18  2018.04.28.b  28-Apr-2018  2018.0  Unprovoked    COSTA RICA
# 21  2018.04.25.a  25-Apr-2018  2018.0  Unprovoked     AUSTRALIA
# 23    2018.04.23  23-Apr-2018  2018.0  Unprovoked      MALDIVES
# 24    2018.04.22  22-Apr-2018  2018.0  Unprovoked  SOUTH AFRICA
# 34    2018.04.03  03-Apr-2018  2018.0  Unprovoked  SOUTH AFRICA
# 35    2018.03.31  31-Mar-2018  2018.0  Unprovoked           USA
# 36    2018.03.14  14-Mar-2018  2018.0  Unprovoked     AUSTRALIA
# 37  2018.03.09.b   9-Mar-2018  2018.0  Unprovoked     AUSTRALIA
# 38  2018.03.09.a   9-Mar-2018  2018.0  Unprovoked     AUSTRALIA
# ...

# %%
shark.sort_values(['Country',],  ).head(50)
# Out:
#       Data    Year         Date         Country                   Area  \
# 4286  1955  1955.0  08-Aug-1955  AMERICAN SAMOA         Tutuila Island
# 4131  1958  1958.0  12-Dec-1958  AMERICAN SAMOA         Tutuila Island
# 4349  1954  1954.0  22-Jan-1954       ARGENTINA  Buenos Aires Province
# 1968  2001  2001.0  02-Apr-2001       AUSTRALIA        New South Wales
# 2829  1986  1986.0  01-Feb-1986       AUSTRALIA               Victoria
# 697   2013  2013.0  10-Mar-2013       AUSTRALIA      Western Australia
# 2857  1985  1985.0  03-Mar-1985       AUSTRALIA        South Australia
# 2870  1984  1984.0  30-Nov-1984       AUSTRALIA             Queensland
# 2927  1983  1983.0  26-Jul-1983       AUSTRALIA             Queensland
# 1116  2009  2009.0  27-Jun-2009       AUSTRALIA        New South Wales
# 2929  1983  1983.0  25-Jul-1983       AUSTRALIA             Queensland
# 2700  1989  1989.0  03-Jan-1989       AUSTRALIA        New South Wales
# ...

# %%
shark.sort_values(['Data', 'Country','Area'], ascending = False).head(50)
# Out:
#      Data    Year         Date       Country                   Area  \
# 35   2018  2018.0  31-Mar-2018           USA                 Hawaii
# 8    2018  2018.0  26-May-2018           USA                Florida
# 0    2018  2018.0  25-Jun-2018           USA             California
# 24   2018  2018.0  22-Apr-2018  SOUTH AFRICA  Western Cape Province
# 34   2018  2018.0  03-Apr-2018  SOUTH AFRICA  Eastern Cape Province
# 23   2018  2018.0  23-Apr-2018      MALDIVES      Alifu Alifu Atoll
# 13   2018  2018.0  13-May-2018       ENGLAND               Cornwall
# 18   2018  2018.0  28-Apr-2018    COSTA RICA           Cocos Island
# 6    2018  2018.0  03-Jun-2018        BRAZIL             Pernambuco
# 51   2018  2018.0  12-Jan-2018        BRAZIL    Fernando de Noronha
# 21   2018  2018.0  25-Apr-2018     AUSTRALIA      Western Australia
# 36   2018  2018.0  14-Mar-2018     AUSTRALIA      Western Australia
# 37   2018  2018.0   9-Mar-2018     AUSTRALIA               Victoria
# ...

# %% [markdown]
# ## Anos com mais ataques

# %%
shark['Year'].value_counts()
# Out:
# 2015.0    63
# 2012.0    55
# 2002.0    53
# 2007.0    52
# 2013.0    50
#           ..
# 1919.0     1
# 1924.0     1
# 1944.0     1
# 1943.0     1
# 1916.0     1
# Name: Year, Length: 106, dtype: int64

# %%
pd.merge(left = shark['Year'].value_counts(normalize = True)*100, right = shark, left_index = True, right_on = 'Year')
# Out:
#         Year    Year_x   Case Number         Date  Year_y        Type  \
# 322   2015.0  4.393305    2015.12.22  22-Dec-2015  2015.0  Unprovoked
# 323   2015.0  4.393305  2015.12.21.b  21-Dec-2015  2015.0  Unprovoked
# 329   2015.0  4.393305    2015.11.20  20-Nov-2015  2015.0  Unprovoked
# 333   2015.0  4.393305    2015.11.10  10-Nov-2015  2015.0  Unprovoked
# 336   2015.0  4.393305  2015.11.01.b  01-Nov-2015  2015.0  Unprovoked
# ...      ...       ...           ...          ...     ...         ...
# 5273  1919.0  0.069735    1919.01.09  09-Jan-1919  1919.0  Unprovoked
# 5192  1924.0  0.069735    1924.01.19  09-Jan-1924  1924.0  Unprovoked
# 4644  1944.0  0.069735    1944.07.22   22-Jul-144  1944.0  Unprovoked
# 4667  1943.0  0.069735    1943.09.23  23-Sep-1943  1943.0  Unprovoked
# 5311  1916.0  0.069735    1916.07.01  01-Jul-1916  1916.0  Unprovoked
#
#            Country                   Area  \
# 322            USA                 Hawaii
# ...

# %%
shark.groupby('Year').count()['Country'].plot(kind = 'bar', figsize=(25, 15))
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ## Rank de Países

# %%
# %matplotlib inline

shark['Country'].value_counts(normalize = True).plot(kind = 'bar', figsize=(25, 15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##  Teste Visualização

# %%
from pandas_profiling import ProfileReport

# %%
grafic_shark = ProfileReport(shark)

# %%
grafic_shark
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-01-26 12:01:44.861286&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
